# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(resp.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko"> <head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="오늘+날씨 : 네이버 뉴스검색" property="og:title"/> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'오늘+날씨'의 네이버 뉴스검색 결과입니다." property="og:description"/> <meta content="'오늘+날씨'의 네이버 뉴스검색 결과입니다." lang="ko" name="description"/> <title>오늘+날씨 : 네이버 뉴스검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"/><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200109.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_200102.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_190612.css" rel="stylesheet" type="text/css"/><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; expires=" + exdate.toUTCString(); } } cookie = cookie + "; path=/"; if (domain != null) { cookie = cookie + "; domain=" + domain; } document.cookie = cookie; }, get : function (key) { var cookie_list = document.cookie.split(/\s*;\s*/); for (var i = 0; i < cookie_list.length; i++) { var tmp_list = cookie_list[i].split("="); var c_key = tmp_list[0].trim(); var c_value = tmp_list[1]; if (key == c_key) { return unescape(c_value); } } return null; } } })(); naver.search.https = window.location.protocol == "https:"; naver.search.meta_referrer = 0; var _nx_js_load = (function () { var scrs = {} ; return  ...
# </div><div class="sub_pack" id="sub_pack"><div class="z_aside section" id="nxfr_htp"> <div class="section_head"><h2>뉴스토픽</h2></div> <div class="realtime_srch _aside_news_tab"> <div class="hotkwd"> <ul class="api_realtime_tab _tab"> <li class="selected" data-blind-text="뉴스토픽 뉴스" data-index="0"><a href="#" onclick="return tCR('htk.nws', 1, '');">뉴스</a></li> <li data-blind-text="뉴스토픽 연예·스포츠" data-index="1"><a href="#" onclick="return tCR('htk.ents', 1, '');">연예·스포츠</a></li> </ul> </div> <h6 class="blind _blind">뉴스토픽 뉴스</h6> <ol class="lst_realtime_srch _tab_area"><li><a class="bx bx_item" href="?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%EB%AF%B8%EA%B5%AD%EC%84%9C%EB%8F%84+%EC%9A%B0%ED%95%9C+%ED%8F%90%EB%A0%B4" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=1&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">1</em><span class="tit">미국서도 우한 폐렴</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li><li><a class="bx bx_item" href="?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=10%EB%85%84+%EB%A7%8C%EC%97%90+%EC%B5%9C%EC%A0%80" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=2&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">2</em><span class="tit">10년 만에 최저</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li><li><a class="bx" href="?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%EB%8C%80%EA%B5%AC%EA%B2%BD%EB%B6%81+%ED%86%B5%ED%95%A9%EC%8B%A0%EA%B3%B5%ED%95%AD" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=3&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">3</em><span class="tit">대구경북 통합신공항</span></span></a></li><li><a class="bx" href="?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%EC%8B%A0%EC%A2%85+%EC%BD%94%EB%A1%9C%EB%82%98%EB%B0%94%EC%9D%B4%EB%9F%AC%EC%8A%A4" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=4&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">4</em><span class="tit">신종 코로나바이러스</span></span></a></li><li><a class="bx bx_item" href="?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%EC%95%88%EB%82%98%ED%91%B8%EB%A5%B4%EB%82%98+%EC%82%AC%EA%B3%A0%ED%8C%80+%EA%B5%90%EC%82%AC%EB%93%A4+%EA%B7%80%EA%B5%AD" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=5&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">5</em><span class="tit">안나푸르나 사고팀 교사들 귀국</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li><li><a class="bx bx_item" href="?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%EC%98%A4%EB%8A%98+%EB%82%A0%EC%94%A8" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=6&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">6</em><span class="tit">오늘 날씨</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li><li><a class="bx bx_item" href="?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%EC%9E%91%EB%85%84+%EC%84%B1%EC%9E%A5%EB%A5%A0+2.0%25" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=7&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">7</em><span class="tit">작년 성장률 2.0%</span></span><em class="rank new"><span class="spim"></span><span>NEW</span></em></a></li><li><a class="bx" href="?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%E4%B8%AD%EC%9A%B0%ED%95%9C+%ED%8F%90%EB%A0%B4" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=8&amp;i=&amp;u='+urlencode(urlexpand(this.href)));"><span class="keyword"><em class="num">8</em><span class="tit">中우한 폐렴</span></span></a></li><li><a class="bx" href="?where=nexearch&amp;sm=tab_htk.nws&amp;ie=utf8&amp;query=%EA%B5%B0%EC%9C%84%EB%83%90+%EC%9D%98%EC%84%B1%EC%9D%B4%EB%83%90" onclick="return goOtherCR(this, 'a=htk.nwslist&amp;r=9&amp;i=&amp;u='+urlencode(urlexpand(this.href))) ...

# %%
#url분석
url ='https://search.naver.com/search.naver'
params = {
    'where': 'news',
    'query': '오늘+날씨'
}

# %%
resp = requests.get(url, params=params)
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="\xec\x98\xa4\xeb\x8a\x98+\xeb\x82\xa0\xec\x94\xa8 : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4\xea\xb2\x80\xec\x83\x89"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'\xec\x98\xa4\xeb\x8a\x98+\xeb\x82\xa0\xec\x94\xa8\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4."> <meta name="description" lang="ko" content="\'\xec\x98\xa4\xeb\x8a\x98+\xeb\x82\xa0\xec\x94\xa8\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4."> <title>\xec\x98\xa4\xeb\x8a\x98+\xeb\x82\xa0\xec\x94\xa8 : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4\xea\xb2\x80\xec\x83\x89</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200109.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_200102.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_190612.css"><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\\s\\uFEFF\\xA0]+|[\\s\\uFEFF\\xA0]+$/g, \'\'); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError(\'"this" is null or not defined\'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === \'undefined\') d = \'|\' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== \'undefined\') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTi ...

# %%
resp.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="오늘+날씨 : 네이버 뉴스검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'오늘+날씨\'의 네이버 뉴스검색 결과입니다."> <meta name="description" lang="ko" content="\'오늘+날씨\'의 네이버 뉴스검색 결과입니다."> <title>오늘+날씨 : 네이버 뉴스검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200109.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_200102.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_190612.css"><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\\s\\uFEFF\\xA0]+|[\\s\\uFEFF\\xA0]+$/g, \'\'); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError(\'"this" is null or not defined\'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === \'undefined\') d = \'|\' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== \'undefined\') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; expires=" + exdate.toUTCString(); } } cookie = cookie + "; path=/"; if (domain != null) { cookie = cookie + "; domain=" + domain; } document.cookie = cookie; }, get : function (key) { var cookie_list = document.cookie.split(/\\s*;\\s*/); for (var i = 0; i < cookie_list.length; i++) { var tmp_list = cookie_list[i].split("="); var c_key = tmp_list[0].trim(); var c_value = tmp_list[1]; if (key == c_key) { return unescape(c_value); } } return null; } } })(); naver.search.https = window.location.protocol == "https:"; naver.search.meta_referrer = 0; var _nx_js_load = (functi ...

# %%
soup = BeautifulSoup(resp.content)

# %%
ul_tag = soup.find('ul', class_='type01')

# %%
news_li_tag = ul_tag.find_all('li', recursive=False)

# %%
len(news_li_tag)
# Out:
# 10

# %%
my_news_list = []

for news_tag in news_li_tag:
    a_tag = news_tag.find('a', class_='_sp_each_title')
    
    title = a_tag.text
    link = a_tag.get('href')
    desc = news_tag.find_all('dd')[1].text
    
    my_news_list.append({
        'title' : title,
        'link' : link,
        'desc' : desc
    })
    
for idx, my_news in enumerate(my_news_list):
    resp = requests.get(my_news.get('link'))
    soup = BeautifulSoup(resp.content)
    
    my_news_list[idx]['content'] = soup.find('body')

# %%
my_news_list
# Out:
# [{'title': '[날씨] 오늘 충청 이남 비...중북부 흐리고 낮 포근',
#   'link': 'https://www.ytn.co.kr/_ln/0108_202001220624043860',
#   'desc': '오늘은 온화한 날씨 속에 충청과 남부 지방에는 겨울비가 내리겠습니다. 지금 남쪽에서 기압골이... 서울 아침 기온 0.1도로 어제보다 6도가량 높은데요, 낮에는 8도까지 올라 포근하겠습니다. 오늘 경기 남부와 충남은...'},
#  {'title': '[오늘(22일)날씨] 전국 대체로 흐리고 비소식…인천·경기남부·충남 미세먼지...',
#   'link': 'http://www.civicnews.com/news/articleView.html?idxno=27249',
#   'desc': '오늘(22일)은 전국 대부분 지역이 대체로 흐린 가운데 제주도와 전남에서 시작된 비가 충청도 및 경북... 22일 낮 최고 기온은 ▲서울·경기·인천 6 ~ 9도 ▲부산·울산·경남 7 ~ 11도 ▲대구·경북 5 ~ 11도 ▲광주·전남 6...'},
#  {'title': '[날씨] 충청이남 비·눈, 내일 전국 확대…큰 추위 없어',
#   'link': 'http://www.yonhapnewstv.co.kr/MYH20200122003200038/?did=1825m',
#   'desc': '설 연휴를 앞두고 눈, 비 소식이 있습니다. 오늘은 충청도와 남부지방을 중심으로 내리겠고, 내일은 전국으로 확대될 텐데요. 자세한 날씨는 기상캐스터 연결해 알아보겠습니다. 구본아 캐스터. [캐스터] 네, 보통 설 연휴...'},
#  {'title': '[일기예보]기상청 오늘 날씨, 서울-경기-부산-제주-인천-강원도-대구-대전-천...',
#   'link': 'http://www.polinews.co.kr/news/article.html?no=449960',
#   'desc': '*주요지역별 날씨 *경기도 경기도는 제주도서쪽 해상에서 다가오는 기압골의 영향으로 구름이 많겠다. 기상청에 따르면 이날 아침 최저기온은 -6~1도, 낮 최고기온은 6~9도다. 시·군별 예상 기온은 수원 -1~7도, 파주...'},
#  {'title': '[오늘 날씨] 흐리고 많은 비, 제주도 최고 120mm...설 연휴 예보는?',
#   'link': 'http://www.headlinejeju.co.kr/news/articleView.html?idxno=407073',
#   'desc': '흐리고, 오전까지 비가 내릴 것으로 예보됐다. 한편, 설 연휴 기간인 24일부터 27일까지는 전국이 대체로 흐린 가운데, 설명절인 25일부터는 제주도를 중심으로 비 날씨가 이어질 것으로 전망되고 있다.\xa0 <헤드라인제주>'},
#  {'title': "[오늘 날씨]22일(수)영상권 회복 '포근'… 미세먼지 '나쁨'",
#   'link': 'http://theleader.mt.co.kr/articleView.html?no=2020012209167877795',
#   'desc': '최고 기온이\xa05~11(평년 0~7도)도로 평년보다 5~6도 높을 것으로\xa0예상된다. 기상청은 이날 제주도 서쪽 해상에서 다가오는 기압골의 영향을 차차 받아 전국이 대체로 흐리다고 21일 예보했다.\xa0오전 3~6시 제주도에 비...'},
#  {'title': "진주 날씨? 오늘의 날씨와 내일의 날씨는 '설연휴 많이 추울까?'",
#   'link': 'http://www.ggilbo.com/news/articleView.html?idxno=740240',
#   'desc': '발표되는 기상정보를 참고하기 바란다. [지역별 오늘의 날씨, 내일 날씨 예보, 일출 시간, 일몰 시간]... 기온은 -4~0도(청주 0도, 체감온도 -1도) 가량 되겠다. 비 또는 눈(높은 산지)이 내리는 지역에서는 가시거리가...'},
#  {'title': "[오늘날씨] 전국 흐리고 곳곳에서 비…수도권 미세먼지 '나쁨'",
#   'link': 'http://www.youthdaily.co.kr/news/article.html?no=27123',
#   'desc': '먼바다 파고는 서해 0.5∼2.0ｍ, 남해 0.5∼2.5ｍ, 동해 1.0∼2.0ｍ로 예보됐다. 다음은 22일 지역별 날씨 전망. [오전, 오후] (최저∼최고기온) <오전, 오후 강수 확률> ▲ 서울 : [흐림, 구름많음] (-1∼8) <30, 20> ▲ 인천...'},
#  {'title': '기상청 오늘 날씨, 서울-경기-부산-제주-인천-강원도-대구-대전-천안-광주 등...',
#   'link': 'http://www.kmaeil.com/news/articleView.html?idxno=209248',
#   'desc': "미세먼지 농도는 '보통'으로 예보됐다. *인천 인천 지역은 제주도 서쪽 해상에서 다가오는 기압골의 영향을 차차 받아 대체로 흐리겠다. 수도권기상청 인천기상대에 따르면 이날 아침 최저기온은 강화군 -5도..."},
#  {'title': '[날씨] 오늘 충청·남부 비…내일 전국 확대',
#   'link': 'http://news.kbs.co.kr/news/view.do?ncd=4367145&ref=A',
#   'desc': "설 연휴까지 포근한 날씨가 이어지겠지만 비 소식이 자주 들어있습니다. 설 당일에는 강원 영동과 제주에 비가 내리겠습니다. 오늘 경기 남부와 충남 지역은 미세먼지 농도 '나쁨' 수준이 예상되고 그 밖의 지역은..."}]

# %%
url ='https://finance.naver.com/item/sise.nhn'
params = {
    'code' : '005930',
    'thistime' : '20200122132807'
}

# %%
resp = requests.get(url, params=params)
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'<!--  global include -->\n\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\t<title>\xbb\xef\xbc\xba\xc0\xfc\xc0\xda : \xb3\xd7\xc0\xcc\xb9\xf6 \xb1\xdd\xc0\xb6</title>\n\t\n\t\n\n\n\n\n\n\t\n\t\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t\n\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n\n\n\n\t\n\t\t<meta property="og:title" content="\xb3\xd7\xc0\xcc\xb9\xf6 \xb1\xdd\xc0\xb6"/>\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t<meta property="og:url" content="https://finance.naver.com"/>\n\t\t<meta property="og:description" content="\xb1\xb9\xb3\xbb \xc7\xd8\xbf\xdc \xc1\xf5\xbd\xc3 \xc1\xf6\xbc\xf6, \xbd\xc3\xc0\xe5\xc1\xf6\xc7\xa5, \xc6\xdd\xb5\xe5, \xb4\xba\xbd\xba, \xc1\xf5\xb1\xc7\xbb\xe7 \xb8\xae\xbc\xad\xc4\xa1 \xb5\xee \xc1\xa6\xb0\xf8"/>\n    \n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="\xb3\xd7\xc0\xcc\xb9\xf6\xb1\xdd\xc0\xb6"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n<link rel=\'stylesheet\' type=\'text/css\' href=\'/css/finance_header.css?20200107172122\'>\n\n\t\n\t\n\t\n\t\n\t\t\n\t\t<link rel="stylesheet" type="text/css" href="/css/newstock.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/common.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/layout.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/main.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/newstock2.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/newstock3.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/world.css?20200107172122">\n\t\t\n\t\t\n\t\t\n\t\t\n\n\t\t\n\t\t\n\t\t\n\t\t\t<script type="text/javascript" src="/js/jindo.min.ns.1.5.3.euckr.js?20200107172122"></script>\n\t\t\t\n\t\t\t\n\t\t\t\t<script type="text/javascript" src="/js/release/common.js?20200107172122"></script>\n\t\t\t\n\t\t\n\t\t\t<script type="text/javascript" src="/js/jindoComponent/jindo.Component.1.0.3.js?20200107172122"></script>\n\t\t\t<script type="text/javascript" src="/ac/nhn.autocomplete.stock.js?20200107172122"></script>\n\t\t\n\t\t\n\t\n\n\n\t<link rel="shortcut icon" href="https://www.naver.com/favicon.ico?20200107172122" type="image/x-icon">\n\t\n\t<script type="text/javascript">\n    (function(){\n        var sUserAgent = navigator.userAgent;\n        if(/iPhone|iPad/.test(sUserAgent)){\n            document.write(\n                [\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_120X120_iphone.png" />\',\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_152x152_ipad.png" />\',\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_167x167_ipad_pro.png" />\',\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_180x180_iphone.png" />\'\n                ]\n                .join(\'\\n\')\n            );\n        }\n\n        if(/Android/.test(sUserAgent)){\n            document.write(\n                [\n                    \'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static/nfinance/ico/2018_android_72x72_xxxhpdi.png" />\',\n                    \'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static/nfinance/ico/2018_android_96x96_xxxhpdi.png" />\',\n                    \'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static/nfinance/ico/2018_android_144 ...

# %%
resp.text
# Out:
# '<!--  global include -->\n\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\t<title>삼성전자 : 네이버 금융</title>\n\t\n\t\n\n\n\n\n\n\t\n\t\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t\n\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n\n\n\n\t\n\t\t<meta property="og:title" content="네이버 금융"/>\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t<meta property="og:url" content="https://finance.naver.com"/>\n\t\t<meta property="og:description" content="국내 해외 증시 지수, 시장지표, 펀드, 뉴스, 증권사 리서치 등 제공"/>\n    \n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="네이버금융"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n<link rel=\'stylesheet\' type=\'text/css\' href=\'/css/finance_header.css?20200107172122\'>\n\n\t\n\t\n\t\n\t\n\t\t\n\t\t<link rel="stylesheet" type="text/css" href="/css/newstock.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/common.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/layout.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/main.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/newstock2.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/newstock3.css?20200107172122">\n\t\t<link rel="stylesheet" type="text/css" href="/css/world.css?20200107172122">\n\t\t\n\t\t\n\t\t\n\t\t\n\n\t\t\n\t\t\n\t\t\n\t\t\t<script type="text/javascript" src="/js/jindo.min.ns.1.5.3.euckr.js?20200107172122"></script>\n\t\t\t\n\t\t\t\n\t\t\t\t<script type="text/javascript" src="/js/release/common.js?20200107172122"></script>\n\t\t\t\n\t\t\n\t\t\t<script type="text/javascript" src="/js/jindoComponent/jindo.Component.1.0.3.js?20200107172122"></script>\n\t\t\t<script type="text/javascript" src="/ac/nhn.autocomplete.stock.js?20200107172122"></script>\n\t\t\n\t\t\n\t\n\n\n\t<link rel="shortcut icon" href="https://www.naver.com/favicon.ico?20200107172122" type="image/x-icon">\n\t\n\t<script type="text/javascript">\n    (function(){\n        var sUserAgent = navigator.userAgent;\n        if(/iPhone|iPad/.test(sUserAgent)){\n            document.write(\n                [\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_120X120_iphone.png" />\',\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_152x152_ipad.png" />\',\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_167x167_ipad_pro.png" />\',\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_180x180_iphone.png" />\'\n                ]\n                .join(\'\\n\')\n            );\n        }\n\n        if(/Android/.test(sUserAgent)){\n            document.write(\n                [\n                    \'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static/nfinance/ico/2018_android_72x72_xxxhpdi.png" />\',\n                    \'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static/nfinance/ico/2018_android_96x96_xxxhpdi.png" />\',\n                    \'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static/nfinance/ico/2018_android_144x144_xxxhpdi.png" />\',\n                    \'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static/nfinance/ico/2018_android_192x192_xxxhpdi.png" />\'\n\t\t\t\t]\n\t\t\t\t.join(\'\\n\')\n\t\t\t);\n        }\n    })();\n    </script>\n</head>\n\n\n\n\n<body onload=\'g ...

# %%
soup = BeautifulSoup(resp.content)

# %%
_type = input('형식: (day or time): ')
stock_code = input("종목코드: ")
page_num = int(input("페이지 (-1은 끝까지)"))

url = 'https://finance.naver.com/item/sise_{0}.nhn'.format(_type)

params = {
    'code': stock_code,
    'thistime': '20200122140411'
}

if (page_num == -1):
    page_num = 1000000000

result_list = []
for i in range(1, page_num+1):
    params['page'] = i
    resp = requests.get(url, params=params)
    
    soup = BeautifulSoup(resp.content)
    stock_table = soup.find('table', class_='type2')
    
    tr_tags = stock_table.find_all('tr')
    
    for tr_tag in tr_tags:
        td_tag = tr_tag.find_all('td')
        
        if len(td_tag) < 7:
            continue
        result_list.append({
            'time': td_tag[0].text,
            'price': td_tag[1].text,
            'relative': td_tag[2].text.strip(),
            'sell': td_tag[3].text,
            'buy': td_tag[4].text,
            'trade_amount': td_tag[5].text,
            'changing_amount': td_tag[6].text
        })
    print(result_list)
    if len(tr_tags) < 10:
        break
#         체결시각	체결가	전일비	매도	매수	거래량	변동량
